# %% [markdown]
# ## Importing data through api key

# %%
import pandas as pd
import requests

# %%
## API KEY PASTE
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7f6b518baa13ce1de93171a3cf48a130&language=en-US&page=1')

# %% [markdown]
# ## 6 col select code

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]

# %% [markdown]
# ## Df show

# %%
df
# Out:
#         id                                          title release_date  \
# 0      278                       The Shawshank Redemption   1994-09-23
# 1      238                                  The Godfather   1972-03-14
# 2      240                          The Godfather Part II   1974-12-20
# 3      424                               Schindler's List   1993-12-15
# 4      389                                   12 Angry Men   1957-04-10
# 5      129                                  Spirited Away   2001-07-20
# 6      155                                The Dark Knight   2008-07-16
# 7    19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 8      497                                 The Green Mile   1999-12-10
# 9   496243                                       Parasite   2019-05-30
# 10     122  The Lord of the Rings: The Return of the King   2003-12-17
# 11     680                                   Pulp Fiction   1994-09-10
# ...

# %%
df.head()
# Out:
#     id                     title release_date  \
# 0  278  The Shawshank Redemption   1994-09-23
# 1  238             The Godfather   1972-03-14
# 2  240     The Godfather Part II   1974-12-20
# 3  424          Schindler's List   1993-12-15
# 4  389              12 Angry Men   1957-04-10
#
#                                             overview  popularity  vote_average
# 0  Imprisoned in the 1940s for the double murder ...     26.1332         8.700
# 1  Spanning the years 1945 to 1955, a chronicle o...     25.2389         8.685
# 2  In the continuing saga of the Corleone crime f...     19.8566         8.571
# 3  The true story of how businessman Oskar Schind...     12.9693         8.566
# 4  The defense and the prosecution have rested an...     11.4362         8.500

# %% [markdown]
# ## Get a Data from page 5

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=7f6b518baa13ce1de93171a3cf48a130&language=en-US&page=5')

# %%
df1=pd.DataFrame(response.json()['results'])[['id','title','release_date','overview','popularity','vote_average']]
df1.head()
# Out:
#        id                  title release_date  \
# 0    8587          The Lion King   1994-06-15
# 1  637920  Miracle in Cell No. 7   2019-10-10
# 2   29259                Le Trou   1960-03-18
# 3   10376     The Legend of 1900   1998-10-28
# 4     670                 Oldboy   2003-11-21
#
#                                             overview  popularity  vote_average
# 0  Young lion prince Simba, eager to one day beco...     15.2997         8.256
# 1  Separated from his daughter, a father with an ...      6.5789         8.300
# 2  Four prison inmates have been hatching a plan ...      2.5623         8.300
# 3  The story of a virtuoso piano player who lives...      8.0955         8.247
# 4  With no clue how he came to be imprisoned, dru...     10.3045         8.245

# %%
df1.shape
# Out:
# (20, 6)

# %%
df.shape
# Out:
# (20, 6)

# %% [markdown]
# ## converting df1 to csv

# %%
df1.to_csv('movies.csv')

# %%
df1
# Out:
#         id                                     title release_date  \
# 0     8587                             The Lion King   1994-06-15
# 1   637920                     Miracle in Cell No. 7   2019-10-10
# 2    29259                                   Le Trou   1960-03-18
# 3    10376                        The Legend of 1900   1998-10-28
# 4      670                                    Oldboy   2003-11-21
# 5   572154  Rascal Does Not Dream of a Dreaming Girl   2019-06-15
# 6   504253               I Want to Eat Your Pancreas   2018-09-01
# 7   630566                                    Clouds   2020-10-09
# 8   447362                            Life in a Year   2020-11-27
# 9   299534                         Avengers: Endgame   2019-04-24
# 10     603                                The Matrix   1999-03-31
# 11  299536                    Avengers: Infinity War   2018-04-25
# 12  527641                           Five Feet Apart   2019-03-14
# ...

# %%
df.to_csv('movies_page1.csv')
